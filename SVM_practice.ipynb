# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from matplotlib.colors import ListedColormap

# %%
glass = pd.read_csv('/content/sample_data/glass.csv')

# %%
glass
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

filtered_data = glass[(glass['Type'] == 3) | (glass['Type'] == 5)]


# Creating a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.scatter(filtered_data.iloc[:, 3], filtered_data.iloc[:, 5], c=filtered_data['Type'], s=100, cmap='coolwarm', edgecolor='white', linewidth=0.5)

# Adding labels
ax.set_xlabel('Label1')
ax.set_ylabel('Labe2')
ax.set_ylabel('Z Label')

# Show plot
plt.show()

# %%
filtered_data = glass[(glass['Type'] == 3) | (glass['Type'] == 5)]

# Scatter plot of filtered data
plt.scatter(filtered_data.iloc[:, 3], filtered_data.iloc[:, 5],
            c=filtered_data['Type'], s=100, cmap='coolwarm', edgecolor='white', linewidth=0.5)

# Additional plotting details
plt.colorbar()  # Adds a color scale
plt.xlabel('Feature 1')  # Replace with actual feature name
plt.ylabel('Feature 2')  # Replace with actual feature name
plt.title('Scatter Plot of Predictions 1 and 2 from Type')
plt.show()

# %%
plt.figure(figsize = (8,6))

sns.heatmap(glass.corr(), annot = True, cmap = 'coolwarm', linewidth = 1.5)
plt.show()

# %%
glass.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %% [markdown]
# **Dropping the Specific Rowa**

# %%
glass['Al'].mean()
# Out:
# 1.444906542056075

# %%
glass.loc[glass['Al'] > 2.3, 'Al'] = glass['Al'].mean()

# %%
shape = glass.shape
shape
# Out:
# (214, 10)

# %%
plt.figure(figsize = (6,5))

sns.boxplot(glass['Al'])
plt.show()

# %%
count = (glass['Al'] > 2.2).sum()
count
# Out:
# 3

# %%
glass.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.366793   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.369190    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.560000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    2.270000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
#glass.drop(glass[glass['Al'] > 2.3].index, axis=0, inplace=True)

# %%
glass
# Out:
#           RI     Na    Mg        Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.100000  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.360000  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.540000  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.290000  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.240000  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...       ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  1.444907  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.990000  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.020000  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.940000  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.080000  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
glass.loc[glass['RI'] >1.523, 'RI'] = glass['RI'].mean()

# %%
plt.figure(figsize = (6,5))

sns.boxplot(glass['RI'])
plt.show()

# %%
glass.shape
# Out:
# (214, 10)

# %%
gcount = (glass['RI'] > 1.522).sum()
gcount
# Out:
# 9

# %%
#glass.drop(glass[glass['RI']>1.524].index, axis = 0, inplace = True)

# %%
glass['Na'].min()
# Out:
# 10.73

# %%
glass.loc[glass['Na'] > 15, 'Na'] = glass['Na'].mean()
glass.loc[glass['Na'] < 12, 'Na'] = 12.02

# %%
plt.figure(figsize = (6,5))

sns.boxplot(glass['Na'])
plt.show()

# %%
#glass.drop(glass[glass['Na']> 15].index, axis = 0, inplace = True)

# %%
#glass.drop(glass[glass['Na'] < 12].index, axis = 0, inplace = True)

# %%
glass.loc[glass['Mg'] < 2.5, 'Mg'] = 3.35
glass.loc[glass['Mg'] < 2.8, 'Mg'] = glass['Mg'].mean()

# %%
plt.figure(figsize = (6,5))

sns.boxplot(glass['Mg'])
plt.show()

# %%
glass['Mg'].median()
# Out:
# 3.48

# %%
glass.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.517840   13.386689    3.489968    1.366793   72.650935    0.497056
# std      0.002026    0.670389    0.213536    0.369190    0.774546    0.652192
# min      1.511150   12.020000    2.810000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    3.350000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.518503   13.772500    3.600000    1.560000   73.087500    0.610000
# max      1.523000   14.990000    4.490000    2.270000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
count = (glass['Mg'] > 3.2).sum()
count
# Out:
# 203

# %%
#glass.drop(glass[glass['Mg'] < 2.5].index, axis = 0, inplace = True )

# %%
#glass.drop(glass[glass['Mg'] > 4].index, axis = 0, inplace = True )

# %%
glass.loc[glass['Si'] < 71.5, 'Si'] = glass['Si'].mean()
glass.loc[glass['Si'] > 73.5, 'Si'] = glass['Si'].mean()

# %%
plt.figure(figsize = (6,5))

sns.boxplot(glass['Si'])
plt.show()

# %%
glass.loc[glass['K'] > 1, 'K'] = glass['K'].mean()

# %%
glass.loc[glass['K'] < 0.1, 'K'] = glass['K'].mean()

# %%
plt.figure(figsize = (6,5))

sns.boxplot(glass['K'])
plt.show()

# %%
#glass.drop(glass[glass['Mg'] > 1.50].index, axis = 0, inplace = True )

# %%
glass.drop(['Ba', 'Ca'], axis = 1, inplace = True)
#glass.drop('Ca', axis = 1, inplace = True)

# %%
#glass.loc[glass['Fe'] > 2.5] = glass['Fe'].mean()

# %%
plt.figure(figsize = (6,5))

sns.boxplot(glass['Fe'])
plt.show()

# %%
glass.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Fe        Type
# count  214.000000  214.000000
# mean     0.057009    2.780374
# std      0.097439    2.103739
# min      0.000000    1.000000
# 25%      0.000000    1.000000
# 50%      0.000000    2.000000
# 75%      0.100000    3.000000
# ...

# %%
shape = glass.shape

num_rows_to_drop = int(0.2 * shape[0])

# Drop the last 10% of the rows
glass_droped = glass[:-num_rows_to_drop]

# %%
glass
# Out:
#           RI     Na    Mg    Al     Si     K   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  0.0     1
# ..       ...    ...   ...   ...    ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  0.0     7
#
# [214 rows x 8 columns]

# %%
y_label = glass['Type']
glass.drop('Type', axis = 1, inplace = True)

# %%
glass
# Out:
#           RI     Na    Mg    Al     Si     K   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  0.0
# ..       ...    ...   ...   ...    ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  0.0
#
# [214 rows x 7 columns]

# %%
#glass.drop('Fe', axis = 1, inplace = True)

# %%
plt.figure(figsize = (6,5))

sns.heatmap(glass.corr(), annot = True, cmap = 'coolwarm', linewidth = 1.5)
plt.show()

# %%
#glass.drop('Al', axis = 1, inplace = True)

# %%
#glass.drop('Fe', axis = 1, inplace = True)

# %%
glass
# Out:
#           RI     Na    Mg     Si     K
# 0    1.52101  13.64  4.49  71.78  0.06
# 1    1.51761  13.89  3.60  72.73  0.48
# 2    1.51618  13.53  3.55  72.99  0.39
# 3    1.51766  13.21  3.69  72.61  0.57
# 4    1.51742  13.27  3.62  73.08  0.55
# ..       ...    ...   ...    ...   ...
# 209  1.51623  14.14  0.00  72.61  0.08
# 210  1.51685  14.92  0.00  73.06  0.00
# 211  1.52065  14.36  0.00  73.42  0.00
# 212  1.51651  14.38  0.00  73.61  0.00
# 213  1.51711  14.23  0.00  73.36  0.00
#
# [214 rows x 5 columns]

# %%
"""
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
scaled_data = scaler.fit_transform(glass)
"""

# %%
#scaled_data
# Out:
# array([[ 1.26375712,  0.37057221,  0.68013468, ..., -1.25077399,
#         -1.01538462,  0.        ],
#        [-0.02656546,  0.64305177,  0.08080808, ..., -0.07430341,
#         -0.15384615,  0.        ],
#        [-0.56925996,  0.2506812 ,  0.04713805, ...,  0.24767802,
#         -0.33846154,  0.        ],
#        ...,
#        [ 1.12713472,  1.15531335, -2.34343434, ...,  0.78018576,
#         -1.13846154,  0.        ],
#        [-0.44402277,  1.17711172, -2.34343434, ...,  1.01547988,
#         -1.13846154,  0.        ],
#        [-0.21631879,  1.01362398, -2.34343434, ...,  0.70588235,
#         -1.13846154,  0.        ]])

# %%
"""
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer(method='yeo-johnson')  # use 'box-cox' if data is strictly positive
transformed_data = pt.fit_transform(glass)
"""

# %%
"""
from scipy.stats import mstats
from sklearn.preprocessing import RobustScaler

# Apply Winsorization to each column
winsorized_data = glass.copy()
for column in winsorized_data.columns:
    winsorized_data[column] = mstats.winsorize(winsorized_data[column], limits=[0.05, 0.05])


# Initialize RobustScaler
robust_scaler = RobustScaler()

# Fit and transform the winsorized data
robust_scaled_data = robust_scaler.fit_transform(winsorized_data)
"""

# %%
from sklearn.preprocessing import QuantileTransformer

qt = QuantileTransformer(n_quantiles=214, output_distribution='normal',  random_state=0,)  # can also use 'uniform'
transformed_data = qt.fit_transform(glass)

# %%
transformed_data
#robust_scaled_data
# Out:
# array([[ 0.9580686 ,  0.45669912,  5.19933758, ..., -1.26304566,
#         -0.9487987 , -5.19933758],
#        [-0.07066802,  0.73098432,  0.66345022, ..., -0.12981396,
#         -0.26795703, -5.19933758],
#        [-0.9487987 ,  0.36071855,  0.36071855, ...,  0.4114383 ,
#         -0.34194223, -5.19933758],
#        ...,
#        [ 0.88605692,  1.1532049 , -5.19933758, ...,  1.47265135,
#         -5.19933758, -5.19933758],
#        [-0.69307432,  1.22478224, -5.19933758, ...,  1.72511338,
#         -5.19933758, -5.19933758],
#        [-0.34818729,  1.05575577, -5.19933758, ...,  1.33127485,
#         -5.19933758, -5.19933758]])

# %%
"""
sc = StandardScaler()
scaled_glass = sc.fit_transform(scaled_data)
"""

# %%
"""
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 9))
glass = scaler.fit_transform(glass)
"""
# Out:
# '\nfrom sklearn.preprocessing import MinMaxScaler\n\nscaler = MinMaxScaler(feature_range=(0, 9))\nglass = scaler.fit_transform(glass)\n'

# %%
#glass

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 4)
pca_val = pca.fit_transform(transformed_data)

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=3, random_state=0)

# Fit and transform the data
tsne_scaled = tsne.fit_transform(transformed_data)

# %%
pca_val
# Out:
# array([[ 5.58344427e-02, -5.15987067e+00, -3.94745815e+00,
#         -4.49612223e-03],
#        [-1.40770851e+00, -1.98825909e+00, -5.95224751e-01,
#         -3.36828682e-01],
#        [-1.59547066e+00, -1.65593051e+00, -4.42173534e-02,
#         -1.20494936e+00],
#        [-9.76530703e-01, -2.68215595e+00, -3.77897774e-01,
#         -2.83190077e-02],
#        [-1.24663030e+00, -2.23491901e+00, -3.78449762e-01,
#         -6.55122629e-01],
#        [ 5.08941521e+00,  4.80119025e-01,  7.11835065e-01,
#         -1.54773725e+00],
#        [-1.15525747e+00, -2.36924680e+00, -1.89428647e-01,
#         -5.28347901e-01],
#        [-1.15735002e+00, -2.35362352e+00, -3.27749781e-01,
#         -5.62089621e-01],
#        [-1.26069352e+00, -2.13970796e+00, -5.26984724e-01,
#          6.58239310e-01],
#        [ 4.09190848e+00,  4.61964231e-01, -3.00153021e-01,
#         -7.95746933e-01],
#        [ 4.70850013e+00,  8.75145205e-01,  1.41085259e+00,
#         -1.77906077e+00],
# ...

# %%
"""
plt.figure(figsize = (6,5))

sns.scatterplot(filtered_arr)
plt.show()
"""
# Out:
# '\nplt.figure(figsize = (6,5))\n\nsns.scatterplot(filtered_arr)\nplt.show()\n'

# %%
"""
mask = np.all(pca_val <= 4, axis=1)
filtered_arr = pca_val[mask]
"""
# Out:
# '\nmask = np.all(pca_val <= 4, axis=1)\nfiltered_arr = pca_val[mask]\n'

# %%
"""mask = np.all(pca_val >= -2, axis=1)
filtered_arr = pca_val[mask]"""
# Out:
# 'mask = np.all(pca_val >= -2, axis=1)\nfiltered_arr = pca_val[mask]'

# %%
#x_train, x_test, y_train, y_test = train_test_split(transformed_data, y_label, test_size = 0.2, stratify = y_label, random_state = 42)
#x_train, x_test, y_train, y_test = train_test_split(robust_scaled_data, y_label, test_size = 0.2, stratify = y_label, random_state = 42)
x_train, x_test, y_train, y_test = train_test_split(tsne_scaled, y_label, test_size = 0.2, stratify = y_label, random_state = 42)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.1, 1, 2,  10, 100],
    'gamma': [0.01, 0.1, 1, 10, 100]
}

# Initialize SVC
svc = SVC(kernel='rbf')

# Grid search with cross-validation
grid_search = GridSearchCV(svc, param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Best parameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
print("Best Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'C': 10, 'gamma': 0.1}
# Best Score: 0.6611764705882354

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel='rbf', C = 30, gamma = 0.3)

svm_model.fit(x_train, y_train)
# Out:
# SVC(C=30, gamma=0.3)

# %%
#y_pred = svm_model.predict(x_test)

# %%
y_train_pred = svm_model.predict(x_train)
y_test_pred = svm_model.predict(x_test)

train_accuracy = accuracy_score(y_train, y_train_pred)

# %%
train_accuracy
# Out:
# 0.9883040935672515

# %%
test_accuracy = accuracy_score(y_test, y_test_pred)
test_accuracy
# Out:
# 0.8372093023255814

# %%
from sklearn.svm import SVC

clf = SVC(kernel = 'poly', degree = 5, C = 100, gamma = 'scale', decision_function_shape='ovr')
clf.fit(x_train, y_train)
# Out:
# SVC(C=100, degree=5, kernel='poly')

# %%
y_label.unique()
# Out:
# array([1, 2, 3, 5, 6, 7])

# %%
x_test.shape
# Out:
# (43, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score

# Create a grid of values for the three features
x1_range = np.linspace(x_train[:, 0].min(), x_train[:, 0].max(), 50)
x2_range = np.linspace(x_train[:, 1].min(), x_train[:, 1].max(), 50)
x3_range = np.linspace(x_train[:, 2].min(), x_train[:, 2].max(), 50)

# Create a meshgrid for the three features
x1, x2, x3 = np.meshgrid(x1_range, x2_range, x3_range)

# Flatten the meshgrid
grid_points = np.c_[x1.ravel(), x2.ravel(), x3.ravel()]

# Compute the decision function for the grid points
decision_values = clf.decision_function(grid_points)

# Reshape decision function values to match the meshgrid
decision_values = decision_values.reshape(x1.shape)

# Plotting
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot decision boundary
contour = ax.contourf(x1[:, :, 0], x2[:, :, 0], x3[:, :, 0], decision_values[:, :, 0], levels=[0], cmap='coolwarm', alpha=0.5)

# Plot training points
scatter = ax.scatter(x_train[:, 0], x_train[:, 1], x_train[:, 2], c=y_train, edgecolor='k')

ax.set_xlabel('PCA Component 1')
ax.set_ylabel('PCA Component 2')
ax.set_zlabel('PCA Component 3')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-411-55e71fb63611> in <cell line: 10>()
#       8
#       9 # Create a grid of values for the three features
# ---> 10 x1_range = np.linspace(x_train[:, 0].min(), x_train[:, 0].max(), 50)
#      11 x2_range = np.linspace(x_train[:, 1].min(), x_train[:, 1].max(), 50)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

filtered_data1 = y_pred  == 1
filtered_data2 = y_pred  == 2


# Creating a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.scatter(filtered_data1, filtered_data2, c= y_pred , s=100, cmap='coolwarm', edgecolor='white', linewidth=0.5)

ax.set_xticks(np.linspace(y_pred.min(), y_pred.max(), 10))  # Increase number of ticks on X-axis
ax.set_yticks(np.linspace(y_pred.min(), y_pred.max(), 10))  # Increase number of ticks on Y-axis
ax.set_zticks(np.linspace(y_pred.min(), y_pred.max(), 10))

# Adding labels
ax.set_xlabel('Label1')
ax.set_ylabel('Labe2')
ax.set_ylabel('Z Label')

# Show plot
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Class 1', 'Class 2'])
disp.plot(cmap='Blues')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-5b51f748c8b4> in <cell line: 3>()
#       1 cm = confusion_matrix(y_test, y_pred)
#       2 disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Class 1', 'Class 2'])
# ----> 3 disp.plot(cmap='Blues')
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_plot/confusion_matrix.py in plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw, text_kw)
#     179         if colorbar:
#     180             fig.colorbar(self.im_, ax=ax)
# --> 181         ax.set(
#     182             xticks=np.arange(n_classes),
#     183             yticks=np.arange(n_classes),
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in <lambda>(self, **kwargs)
#     145             return
#     146
# --> 147         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
# ...
