# %%
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/drive')

Iris_dataset = pd.read_excel('/content/drive/MyDrive/Iris.xls')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Iris_dataset
# Out:
#      Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0             1          0.2           1.4          3.5           5.1
# 1             1          0.2           1.4          3.0           4.9
# 2             1          0.2           1.3          3.2           4.7
# 3             1          0.2           1.5          3.1           4.6
# 4             1          0.2           1.4          3.6           5.0
# ..          ...          ...           ...          ...           ...
# 145           3          2.3           5.2          3.0           6.7
# 146           3          1.9           5.0          2.5           6.3
# 147           3          2.0           5.2          3.0           6.5
# 148           3          2.3           5.4          3.4           6.2
# 149           3          1.8           5.1          3.0           5.9
#
#     Species_name
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
# ...

# %%
df = pd.DataFrame(Iris_dataset)

# %%
df.values
# Out:
# array([[1, 0.2, 1.4, 3.5, 5.1, ' Setosa'],
#        [1, 0.2, 1.4, 3.0, 4.9, ' Setosa'],
#        [1, 0.2, 1.3, 3.2, 4.7, ' Setosa'],
#        [1, 0.2, 1.5, 3.1, 4.6, ' Setosa'],
#        [1, 0.2, 1.4, 3.6, 5.0, ' Setosa'],
#        [1, 0.4, 1.7, 3.9, 5.4, ' Setosa'],
#        [1, 0.3, 1.4, 3.4, 4.6, ' Setosa'],
#        [1, 0.2, 1.5, 3.4, 5.0, ' Setosa'],
#        [1, 0.2, 1.4, 2.9, 4.4, ' Setosa'],
#        [1, 0.1, 1.5, 3.1, 4.9, ' Setosa'],
#        [1, 0.2, 1.5, 3.7, 5.4, ' Setosa'],
#        [1, 0.2, 1.6, 3.4, 4.8, ' Setosa'],
#        [1, 0.1, 1.4, 3.0, 4.8, ' Setosa'],
#        [1, 0.1, 1.1, 3.0, 4.3, ' Setosa'],
#        [1, 0.2, 1.2, 4.0, 5.8, ' Setosa'],
#        [1, 0.4, 1.5, 4.4, 5.7, ' Setosa'],
#        [1, 0.4, 1.3, 3.9, 5.4, ' Setosa'],
#        [1, 0.3, 1.4, 3.5, 5.1, ' Setosa'],
#        [1, 0.3, 1.7, 3.8, 5.7, ' Setosa'],
#        [1, 0.3, 1.5, 3.8, 5.1, ' Setosa'],
#        [1, 0.2, 1.7, 3.4, 5.4, ' Setosa'],
#        [1, 0.4, 1.5, 3.7, 5.1, ' Setosa'],
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.describe()
# Out:
#        Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length
# count  150.000000   150.000000    150.000000   150.000000    150.000000
# mean     2.000000     1.199333      3.758000     3.057333      5.843333
# std      0.819232     0.762238      1.765298     0.435866      0.828066
# min      1.000000     0.100000      1.000000     2.000000      4.300000
# 25%      1.000000     0.300000      1.600000     2.800000      5.100000
# 50%      2.000000     1.300000      4.350000     3.000000      5.800000
# 75%      3.000000     1.800000      5.100000     3.300000      6.400000
# max      3.000000     2.500000      6.900000     4.400000      7.900000

# %%
df
# Out:
#      Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0             1          0.2           1.4          3.5           5.1
# 1             1          0.2           1.4          3.0           4.9
# 2             1          0.2           1.3          3.2           4.7
# 3             1          0.2           1.5          3.1           4.6
# 4             1          0.2           1.4          3.6           5.0
# ..          ...          ...           ...          ...           ...
# 145           3          2.3           5.2          3.0           6.7
# 146           3          1.9           5.0          2.5           6.3
# 147           3          2.0           5.2          3.0           6.5
# 148           3          2.3           5.4          3.4           6.2
# 149           3          1.8           5.1          3.0           5.9
#
#     Species_name
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
# ...

# %%
df.sort_values(by = 'Petal_width')
# Out:
#      Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 32            1          0.1           1.5          4.1           5.2
# 13            1          0.1           1.1          3.0           4.3
# 37            1          0.1           1.4          3.6           4.9
# 9             1          0.1           1.5          3.1           4.9
# 12            1          0.1           1.4          3.0           4.8
# ..          ...          ...           ...          ...           ...
# 140           3          2.4           5.6          3.1           6.7
# 114           3          2.4           5.1          2.8           5.8
# 100           3          2.5           6.0          3.3           6.3
# 144           3          2.5           5.7          3.3           6.7
# 109           3          2.5           6.1          3.6           7.2
#
#     Species_name
# 32        Setosa
# 13        Setosa
# 37        Setosa
# 9         Setosa
# 12        Setosa
# ...

# %%
df.sort_index(axis= 0)
# Out:
#      Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0             1          0.2           1.4          3.5           5.1
# 1             1          0.2           1.4          3.0           4.9
# 2             1          0.2           1.3          3.2           4.7
# 3             1          0.2           1.5          3.1           4.6
# 4             1          0.2           1.4          3.6           5.0
# ..          ...          ...           ...          ...           ...
# 145           3          2.3           5.2          3.0           6.7
# 146           3          1.9           5.0          2.5           6.3
# 147           3          2.0           5.2          3.0           6.5
# 148           3          2.3           5.4          3.4           6.2
# 149           3          1.8           5.1          3.0           5.9
#
#     Species_name
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
# ...

# %%
df.head()
# Out:
#    Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0           1          0.2           1.4          3.5           5.1
# 1           1          0.2           1.4          3.0           4.9
# 2           1          0.2           1.3          3.2           4.7
# 3           1          0.2           1.5          3.1           4.6
# 4           1          0.2           1.4          3.6           5.0
#
#   Species_name
# 0       Setosa
# 1       Setosa
# 2       Setosa
# 3       Setosa
# 4       Setosa

# %%
df['Petal_width']
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: Petal_width, Length: 150, dtype: float64

# %%
df[5:8]
# Out:
#    Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 5           1          0.4           1.7          3.9           5.4
# 6           1          0.3           1.4          3.4           4.6
# 7           1          0.2           1.5          3.4           5.0
#
#   Species_name
# 5       Setosa
# 6       Setosa
# 7       Setosa

# %%
df.loc[5:9, ['Petal_length', 'Petal_width']]
# Out:
#    Petal_length  Petal_width
# 5           1.7          0.4
# 6           1.4          0.3
# 7           1.5          0.2
# 8           1.4          0.2
# 9           1.5          0.1

# %%
df[df['Petal_width'] <3 ]

# %%
df2 = df.copy()

# %%
df2
# Out:
#      Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0             1          0.2           1.4          3.5           5.1
# 1             1          0.2           1.4          3.0           4.9
# 2             1          0.2           1.3          3.2           4.7
# 3             1          0.2           1.5          3.1           4.6
# 4             1          0.2           1.4          3.6           5.0
# ..          ...          ...           ...          ...           ...
# 145           3          2.3           5.2          3.0           6.7
# 146           3          1.9           5.0          2.5           6.3
# 147           3          2.0           5.2          3.0           6.5
# 148           3          2.3           5.4          3.4           6.2
# 149           3          1.8           5.1          3.0           5.9
#
#     Species_name
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
# ...

# %%
df2[df2['Species_name'].isin(['hI', 'hELLO'])]
df2
# Out:
#      Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0             1          0.2           1.4          3.5           5.1
# 1             1          0.2           1.4          3.0           4.9
# 2             1          0.2           1.3          3.2           4.7
# 3             1          0.2           1.5          3.1           4.6
# 4             1          0.2           1.4          3.6           5.0
# ..          ...          ...           ...          ...           ...
# 145           3          2.3           5.2          3.0           6.7
# 146           3          1.9           5.0          2.5           6.3
# 147           3          2.0           5.2          3.0           6.5
# 148           3          2.3           5.4          3.4           6.2
# 149           3          1.8           5.1          3.0           5.9
#
#     Species_name
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
# ...

# %%
df2['Species_No']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    3
# 146    3
# 147    3
# 148    3
# 149    3
# Name: Species_No, Length: 150, dtype: int64

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-2e40cf608963> in <cell line: 1>()
# ----> 1 df.apply(lambda x: x.max() - x.min())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10032             kwargs=kwargs,
#   10033         )
# > 10034         return op.apply().__finalize__(self, method="apply")
#   10035
#   10036     def map(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     835             return self.apply_raw()
#     836
# --> 837         return self.apply_standard()
#     838
#     839     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#     963
#     964     def apply_standard(self):
# --> 965         results, res_index = self.apply_series_generator()
#     966
# ...

# %%
frame_one = pd.DataFrame(np.random.randn(5, 4))
frame_one
# Out:
#           0         1         2         3
# 0  0.235405  1.556263 -0.860692  0.220329
# 1  0.286611  1.110642 -0.612035  0.349819
# 2  0.069941  0.032584 -1.945182  0.416922
# 3  1.853006  0.012823  1.226699  1.495398
# 4  0.067630 -0.520627 -0.306234 -0.519363

# %%
frame_two = pd.DataFrame(np.random.randn(5, 4))
frame_two
# Out:
#           0         1         2         3
# 0  0.006669 -0.984825 -0.612461  1.782221
# 1 -1.106588 -1.904647  0.245353 -0.397114
# 2 -0.024767  0.522512 -0.693384 -2.262977
# 3 -1.199124  2.329501 -1.555365 -0.597697
# 4 -0.849492  2.111582  0.898218  1.148751

# %%
pd.concat([frame_one, frame_two])
# Out:
#           0         1         2         3
# 0  0.235405  1.556263 -0.860692  0.220329
# 1  0.286611  1.110642 -0.612035  0.349819
# 2  0.069941  0.032584 -1.945182  0.416922
# 3  1.853006  0.012823  1.226699  1.495398
# 4  0.067630 -0.520627 -0.306234 -0.519363
# 0  0.006669 -0.984825 -0.612461  1.782221
# 1 -1.106588 -1.904647  0.245353 -0.397114
# 2 -0.024767  0.522512 -0.693384 -2.262977
# 3 -1.199124  2.329501 -1.555365 -0.597697
# 4 -0.849492  2.111582  0.898218  1.148751
